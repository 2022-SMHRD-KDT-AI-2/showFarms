# %% [markdown]
# ### 라이브러리

# %%
import torch
import wandb
import os

# %%
torch.cuda.is_available()
# Out:
# True

# %%
# %wandb

# %% [markdown]
# ### YOLOv5 MODEL 학습

# %%
# 학습을 위한 경로 설정
# %cd yolov5
# Out:
# [WinError 2] 지정된 파일을 찾을 수 없습니다: 'yolov5'
# C:\Users\smhrd\Desktop\Dectecting\main\yolov5

# %%
# 학습 캐시 삭제
os.environ['KMP_DUPLICATE_LIB_OK']='True'

# %%
# 첫번째 YOLOv5 학습 모델
# !python train.py --img 640 --batch 16 --epoch 10 --data ../yaml/farms.yaml --cfg ../yaml/yolov5m.yaml --weights "" --workers 1
# Out:
# wandb: Currently logged in as: dasci. Use `wandb login --relogin` to force relogin
# train: weights=, cfg=../yaml/yolov5m.yaml, data=../yaml/farms.yaml, hyp=data\hyps\hyp.scratch-low.yaml, epochs=10, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=1, project=runs\train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5
# YOLOv5  v6.1-202-g7d46c69 Python-3.9.12 torch-1.11.0 CUDA:0 (NVIDIA GeForce RTX 2080 SUPER, 8192MiB)
#
# ...

# %% [markdown]
# ### YOLOv5 MODEL 테스트

# %%
# !python val.py --data ../yaml/farms.yaml --weights ./runs/train/exp2/weights/best.pt
# Out:
# val: data=../yaml/farms.yaml, weights=['./runs/train/exp2/weights/best.pt'], batch_size=32, imgsz=640, conf_thres=0.001, iou_thres=0.6, task=val, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs\val, name=exp, exist_ok=False, half=False, dnn=False
# YOLOv5  v6.1-202-g7d46c69 Python-3.9.12 torch-1.11.0 CUDA:0 (NVIDIA GeForce RTX 2080 SUPER, 8192MiB)
#
# Fusing layers...
# YOLOv5m summary: 290 layers, 20861016 parameters, 0 gradients, 48.0 GFLOPs
#
# val: Scanning 'C:\Users\smhrd\Desktop\Dectecting\main\data\labels\validation.cache' images and labels... 1020 found, 0 missing, 0 empty, 0 corrupt: 100%|##########| 1020/1020 [00:00<?, ?it/s]
# val: Scanning 'C:\Users\smhrd\Desktop\Dectecting\main\data\labels\validation.cache' images and labels... 1020 found, 0 missing, 0 empty, 0 corrupt: 100%|##########| 1020/1020 [00:00<?, ?it/s]
#
# ...
